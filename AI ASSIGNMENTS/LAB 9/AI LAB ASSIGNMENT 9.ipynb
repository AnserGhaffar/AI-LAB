# %% [markdown]
# # NAME: ANSER GHAFFAR
# # ROLL NO: SU92-BSDSM-F23-032
# # SECTION: BSDS 3A
# # AI LAB ASSIGNMENT 9

# %% [markdown]
# # LIBRARIES

# %%
import pandas as pd

# %% [markdown]
# # DATA LOADING

# %%
df = pd.read_csv('processed_data news.csv')
df
# Out:
#      phone_brand            phone_model      store   price currency  \
# 0          apple         Apple iPhone X  Amazon DE  213.85      EUR
# 1          apple         Apple iPhone X  Amazon US  162.90      USD
# 2        samsung     Samsung Galaxy S9+  Amazon DE  117.84      EUR
# 3        samsung     Samsung Galaxy S9+  Amazon DE  279.00      EUR
# 4        samsung     Samsung Galaxy S9+  Amazon DE  309.04      EUR
# ...          ...                    ...        ...     ...      ...
# 1710     samsung  Samsung Galaxy S24 FE  Amazon US  709.99      USD
# 1711     samsung  Samsung Galaxy S24 FE    Samsung  649.99      USD
# 1712     samsung  Samsung Galaxy S24 FE    Samsung  709.99      USD
# 1713     samsung  Samsung Galaxy S24 FE  Amazon UK  649.00      GBP
# 1714     samsung  Samsung Galaxy S24 FE  Amazon UK  699.00      GBP
#
#       price_USD  storage  ram      Launch  \
# 0        231.73      256    3  2017-11-03
# 1        162.90      256    3  2017-11-03
# 2        127.69       64    6  2018-03-01
# 3        302.32      128    6  2018-03-01
# 4        334.88      256    6  2018-03-01
# ...         ...      ...  ...         ...
# 1710     709.99      512    8  2024-10-03
# 1711     649.99      256    8  2024-10-03
# 1712     709.99      512    8  2024-10-03
# 1713     844.35      256    8  2024-10-03
# 1714     909.40      512    8  2024-10-03
#
#                                          Dimensions  ...  \
# 0     143.6 x 70.9 x 7.7 mm (5.65 x 2.79 x 0.30 in)  ...
# 1     143.6 x 70.9 x 7.7 mm (5.65 x 2.79 x 0.30 in)  ...
# 2     158.1 x 73.8 x 8.5 mm (6.22 x 2.91 x 0.33 in)  ...
# 3     158.1 x 73.8 x 8.5 mm (6.22 x 2.91 x 0.33 in)  ...
# 4     158.1 x 73.8 x 8.5 mm (6.22 x 2.91 x 0.33 in)  ...
# ...                                             ...  ...
# 1710      162 x 77.3 x 8 mm (6.38 x 3.04 x 0.31 in)  ...
# 1711      162 x 77.3 x 8 mm (6.38 x 3.04 x 0.31 in)  ...
# 1712      162 x 77.3 x 8 mm (6.38 x 3.04 x 0.31 in)  ...
# 1713      162 x 77.3 x 8 mm (6.38 x 3.04 x 0.31 in)  ...
# 1714      162 x 77.3 x 8 mm (6.38 x 3.04 x 0.31 in)  ...
#
#                          Chipset  \
# 0       Apple A11 Bionic (10 nm)
# 1       Apple A11 Bionic (10 nm)
# 2     Exynos 9810 (10 nm) - EMEA
# 3     Exynos 9810 (10 nm) - EMEA
# 4     Exynos 9810 (10 nm) - EMEA
# ...                          ...
# 1710         Exynos 2400e (4 nm)
# 1711         Exynos 2400e (4 nm)
# 1712         Exynos 2400e (4 nm)
# 1713         Exynos 2400e (4 nm)
# 1714         Exynos 2400e (4 nm)
#
#                                                     CPU  \
# 0          Hexa-core 2.39 GHz (2x Monsoon + 4x Mistral)
# 1          Hexa-core 2.39 GHz (2x Monsoon + 4x Mistral)
# 2     Octa-core (4x2.7 GHz Mongoose M3 & 4x1.8 GHz C...
# 3     Octa-core (4x2.7 GHz Mongoose M3 & 4x1.8 GHz C...
# 4     Octa-core (4x2.7 GHz Mongoose M3 & 4x1.8 GHz C...
# ...                                                 ...
# 1710  10-core (1x3.1 GHz + 2x2.9 GHz + 3x2.6 GHz + 4...
# 1711  10-core (1x3.1 GHz + 2x2.9 GHz + 3x2.6 GHz + 4...
# 1712  10-core (1x3.1 GHz + 2x2.9 GHz + 3x2.6 GHz + 4...
# 1713  10-core (1x3.1 GHz + 2x2.9 GHz + 3x2.6 GHz + 4...
# 1714  10-core (1x3.1 GHz + 2x2.9 GHz + 3x2.6 GHz + 4...
#
#                                   GPU  Year Foldable  PPI_Density  \
# 0     Apple GPU (three-core graphics)  2017        0          458
# 1     Apple GPU (three-core graphics)  2017        0          458
# 2                Mali-G72 MP18 - EMEA  2018        0          529
# 3                Mali-G72 MP18 - EMEA  2018        0          529
# 4                Mali-G72 MP18 - EMEA  2018        0          529
# ...                               ...   ...      ...          ...
# 1710                      Xclipse 940  2024        0          385
# 1711                      Xclipse 940  2024        0          385
# 1712                      Xclipse 940  2024        0          385
# 1713                      Xclipse 940  2024        0          385
# 1714                      Xclipse 940  2024        0          385
#
#                  quantile_10  quantile_50             quantile_90  \
# 0     16.978.300.000.000.000      197.315  22.484.699.999.999.900
# 1     16.978.300.000.000.000      197.315  22.484.699.999.999.900
# 2     14.129.600.000.000.000      214.560                 311.688
# 3     14.129.600.000.000.000      214.560                 311.688
# 4     14.129.600.000.000.000      214.560                 311.688
# ...                      ...          ...                     ...
# 1710                 161.756      552.385               1.380.286
# 1711                 161.756      552.385               1.380.286
# 1712                 161.756      552.385               1.380.286
# 1713                 161.756      552.385               1.380.286
# 1714                 161.756      552.385               1.380.286
#
#        price_range
# 0       high price
# 1        low price
# 2        low price
# 3     medium price
# 4       high price
# ...            ...
# 1710  medium price
# 1711  medium price
# 1712  medium price
# 1713  medium price
# 1714  medium price
#
# [1715 rows x 31 columns]

# %% [markdown]
# # DATA EXPLORATION

# %%
df.head()
# Out:
#   phone_brand         phone_model      store   price currency  price_USD  \
# 0       apple      Apple iPhone X  Amazon DE  213.85      EUR     231.73
# 1       apple      Apple iPhone X  Amazon US  162.90      USD     162.90
# 2     samsung  Samsung Galaxy S9+  Amazon DE  117.84      EUR     127.69
# 3     samsung  Samsung Galaxy S9+  Amazon DE  279.00      EUR     302.32
# 4     samsung  Samsung Galaxy S9+  Amazon DE  309.04      EUR     334.88
#
#    storage  ram      Launch                                     Dimensions  \
# 0      256    3  2017-11-03  143.6 x 70.9 x 7.7 mm (5.65 x 2.79 x 0.30 in)
# 1      256    3  2017-11-03  143.6 x 70.9 x 7.7 mm (5.65 x 2.79 x 0.30 in)
# 2       64    6  2018-03-01  158.1 x 73.8 x 8.5 mm (6.22 x 2.91 x 0.33 in)
# 3      128    6  2018-03-01  158.1 x 73.8 x 8.5 mm (6.22 x 2.91 x 0.33 in)
# 4      256    6  2018-03-01  158.1 x 73.8 x 8.5 mm (6.22 x 2.91 x 0.33 in)
#
#    ...                     Chipset  \
# 0  ...    Apple A11 Bionic (10 nm)
# 1  ...    Apple A11 Bionic (10 nm)
# 2  ...  Exynos 9810 (10 nm) - EMEA
# 3  ...  Exynos 9810 (10 nm) - EMEA
# 4  ...  Exynos 9810 (10 nm) - EMEA
#
#                                                  CPU  \
# 0       Hexa-core 2.39 GHz (2x Monsoon + 4x Mistral)
# 1       Hexa-core 2.39 GHz (2x Monsoon + 4x Mistral)
# 2  Octa-core (4x2.7 GHz Mongoose M3 & 4x1.8 GHz C...
# 3  Octa-core (4x2.7 GHz Mongoose M3 & 4x1.8 GHz C...
# 4  Octa-core (4x2.7 GHz Mongoose M3 & 4x1.8 GHz C...
#
#                                GPU  Year Foldable  PPI_Density  \
# 0  Apple GPU (three-core graphics)  2017        0          458
# 1  Apple GPU (three-core graphics)  2017        0          458
# 2             Mali-G72 MP18 - EMEA  2018        0          529
# 3             Mali-G72 MP18 - EMEA  2018        0          529
# 4             Mali-G72 MP18 - EMEA  2018        0          529
#
#               quantile_10  quantile_50             quantile_90   price_range
# 0  16.978.300.000.000.000      197.315  22.484.699.999.999.900    high price
# 1  16.978.300.000.000.000      197.315  22.484.699.999.999.900     low price
# 2  14.129.600.000.000.000      214.560                 311.688     low price
# 3  14.129.600.000.000.000      214.560                 311.688  medium price
# 4  14.129.600.000.000.000      214.560                 311.688    high price
#
# [5 rows x 31 columns]

# %%
df.tail()
# Out:
#      phone_brand            phone_model      store   price currency  \
# 1710     samsung  Samsung Galaxy S24 FE  Amazon US  709.99      USD
# 1711     samsung  Samsung Galaxy S24 FE    Samsung  649.99      USD
# 1712     samsung  Samsung Galaxy S24 FE    Samsung  709.99      USD
# 1713     samsung  Samsung Galaxy S24 FE  Amazon UK  649.00      GBP
# 1714     samsung  Samsung Galaxy S24 FE  Amazon UK  699.00      GBP
#
#       price_USD  storage  ram      Launch  \
# 1710     709.99      512    8  2024-10-03
# 1711     649.99      256    8  2024-10-03
# 1712     709.99      512    8  2024-10-03
# 1713     844.35      256    8  2024-10-03
# 1714     909.40      512    8  2024-10-03
#
#                                      Dimensions  ...              Chipset  \
# 1710  162 x 77.3 x 8 mm (6.38 x 3.04 x 0.31 in)  ...  Exynos 2400e (4 nm)
# 1711  162 x 77.3 x 8 mm (6.38 x 3.04 x 0.31 in)  ...  Exynos 2400e (4 nm)
# 1712  162 x 77.3 x 8 mm (6.38 x 3.04 x 0.31 in)  ...  Exynos 2400e (4 nm)
# 1713  162 x 77.3 x 8 mm (6.38 x 3.04 x 0.31 in)  ...  Exynos 2400e (4 nm)
# 1714  162 x 77.3 x 8 mm (6.38 x 3.04 x 0.31 in)  ...  Exynos 2400e (4 nm)
#
#                                                     CPU          GPU  Year  \
# 1710  10-core (1x3.1 GHz + 2x2.9 GHz + 3x2.6 GHz + 4...  Xclipse 940  2024
# 1711  10-core (1x3.1 GHz + 2x2.9 GHz + 3x2.6 GHz + 4...  Xclipse 940  2024
# 1712  10-core (1x3.1 GHz + 2x2.9 GHz + 3x2.6 GHz + 4...  Xclipse 940  2024
# 1713  10-core (1x3.1 GHz + 2x2.9 GHz + 3x2.6 GHz + 4...  Xclipse 940  2024
# 1714  10-core (1x3.1 GHz + 2x2.9 GHz + 3x2.6 GHz + 4...  Xclipse 940  2024
#
#      Foldable  PPI_Density quantile_10  quantile_50 quantile_90   price_range
# 1710        0          385     161.756      552.385   1.380.286  medium price
# 1711        0          385     161.756      552.385   1.380.286  medium price
# 1712        0          385     161.756      552.385   1.380.286  medium price
# 1713        0          385     161.756      552.385   1.380.286  medium price
# 1714        0          385     161.756      552.385   1.380.286  medium price
#
# [5 rows x 31 columns]

# %%
for cols in df.columns:
    print(cols)
# Out:
# phone_brand
# phone_model
# store
# price
# currency
# price_USD
# storage
# ram
# Launch
# Dimensions
# Weight
# Display_Type
# Display_Size
# Display_Resolution
# OS
# NFC
# USB
# BATTERY
# Features_Sensors
# Colors
# Video
# Chipset
# CPU
# GPU
# Year
# Foldable
# PPI_Density
# quantile_10
# quantile_50
# quantile_90
# price_range

# %%
df.count()
# Out:
# phone_brand           1715
# phone_model           1715
# store                 1715
# price                 1715
# currency              1715
# price_USD             1715
# storage               1715
# ram                   1715
# Launch                1715
# Dimensions            1715
# Weight                1712
# Display_Type          1715
# Display_Size          1715
# Display_Resolution    1715
# OS                    1715
# NFC                   1715
# USB                   1715
# BATTERY               1715
# Features_Sensors      1715
# Colors                1715
# Video                 1715
# Chipset               1715
# CPU                   1715
# GPU                   1715
# Year                  1715
# Foldable              1715
# PPI_Density           1715
# quantile_10           1715
# quantile_50           1715
# quantile_90           1715
# price_range           1715
# dtype: int64

# %%
df['phone_brand'].unique()
# Out:
# array(['apple', 'samsung', 'huawei', 'oneplus', 'google', 'xiaomi',
#        'realme', 'vivo', 'oppo', 'motorola', 'zte', 'nokia', 'asus',
#        'sony', 'honor', 'infinix', 'nothing', 'tecno', 'tcl', 'htc',
#        'blackview', 'cubot'], dtype=object)

# %%
df.nunique
# Out:
# <bound method DataFrame.nunique of      phone_brand            phone_model      store   price currency  \
# 0          apple         Apple iPhone X  Amazon DE  213.85      EUR
# 1          apple         Apple iPhone X  Amazon US  162.90      USD
# 2        samsung     Samsung Galaxy S9+  Amazon DE  117.84      EUR
# 3        samsung     Samsung Galaxy S9+  Amazon DE  279.00      EUR
# 4        samsung     Samsung Galaxy S9+  Amazon DE  309.04      EUR
# ...          ...                    ...        ...     ...      ...
# 1710     samsung  Samsung Galaxy S24 FE  Amazon US  709.99      USD
# 1711     samsung  Samsung Galaxy S24 FE    Samsung  649.99      USD
# 1712     samsung  Samsung Galaxy S24 FE    Samsung  709.99      USD
# 1713     samsung  Samsung Galaxy S24 FE  Amazon UK  649.00      GBP
# 1714     samsung  Samsung Galaxy S24 FE  Amazon UK  699.00      GBP
#
#       price_USD  storage  ram      Launch  \
# 0        231.73      256    3  2017-11-03
# 1        162.90      256    3  2017-11-03
# 2        127.69       64    6  2018-03-01
# 3        302.32      128    6  2018-03-01
# 4        334.88      256    6  2018-03-01
# ...         ...      ...  ...         ...
# 1710     709.99      512    8  2024-10-03
# 1711     649.99      256    8  2024-10-03
# 1712     709.99      512    8  2024-10-03
# 1713     844.35      256    8  2024-10-03
# 1714     909.40      512    8  2024-10-03
#
#                                          Dimensions  ...  \
# 0     143.6 x 70.9 x 7.7 mm (5.65 x 2.79 x 0.30 in)  ...
# 1     143.6 x 70.9 x 7.7 mm (5.65 x 2.79 x 0.30 in)  ...
# 2     158.1 x 73.8 x 8.5 mm (6.22 x 2.91 x 0.33 in)  ...
# 3     158.1 x 73.8 x 8.5 mm (6.22 x 2.91 x 0.33 in)  ...
# 4     158.1 x 73.8 x 8.5 mm (6.22 x 2.91 x 0.33 in)  ...
# ...                                             ...  ...
# 1710      162 x 77.3 x 8 mm (6.38 x 3.04 x 0.31 in)  ...
# 1711      162 x 77.3 x 8 mm (6.38 x 3.04 x 0.31 in)  ...
# 1712      162 x 77.3 x 8 mm (6.38 x 3.04 x 0.31 in)  ...
# 1713      162 x 77.3 x 8 mm (6.38 x 3.04 x 0.31 in)  ...
# 1714      162 x 77.3 x 8 mm (6.38 x 3.04 x 0.31 in)  ...
#
#                          Chipset  \
# 0       Apple A11 Bionic (10 nm)
# 1       Apple A11 Bionic (10 nm)
# 2     Exynos 9810 (10 nm) - EMEA
# 3     Exynos 9810 (10 nm) - EMEA
# 4     Exynos 9810 (10 nm) - EMEA
# ...                          ...
# 1710         Exynos 2400e (4 nm)
# 1711         Exynos 2400e (4 nm)
# 1712         Exynos 2400e (4 nm)
# 1713         Exynos 2400e (4 nm)
# 1714         Exynos 2400e (4 nm)
#
#                                                     CPU  \
# 0          Hexa-core 2.39 GHz (2x Monsoon + 4x Mistral)
# 1          Hexa-core 2.39 GHz (2x Monsoon + 4x Mistral)
# 2     Octa-core (4x2.7 GHz Mongoose M3 & 4x1.8 GHz C...
# 3     Octa-core (4x2.7 GHz Mongoose M3 & 4x1.8 GHz C...
# 4     Octa-core (4x2.7 GHz Mongoose M3 & 4x1.8 GHz C...
# ...                                                 ...
# 1710  10-core (1x3.1 GHz + 2x2.9 GHz + 3x2.6 GHz + 4...
# 1711  10-core (1x3.1 GHz + 2x2.9 GHz + 3x2.6 GHz + 4...
# 1712  10-core (1x3.1 GHz + 2x2.9 GHz + 3x2.6 GHz + 4...
# 1713  10-core (1x3.1 GHz + 2x2.9 GHz + 3x2.6 GHz + 4...
# 1714  10-core (1x3.1 GHz + 2x2.9 GHz + 3x2.6 GHz + 4...
#
#                                   GPU  Year Foldable  PPI_Density  \
# 0     Apple GPU (three-core graphics)  2017        0          458
# 1     Apple GPU (three-core graphics)  2017        0          458
# 2                Mali-G72 MP18 - EMEA  2018        0          529
# 3                Mali-G72 MP18 - EMEA  2018        0          529
# 4                Mali-G72 MP18 - EMEA  2018        0          529
# ...                               ...   ...      ...          ...
# 1710                      Xclipse 940  2024        0          385
# 1711                      Xclipse 940  2024        0          385
# 1712                      Xclipse 940  2024        0          385
# 1713                      Xclipse 940  2024        0          385
# 1714                      Xclipse 940  2024        0          385
#
#                  quantile_10  quantile_50             quantile_90  \
# 0     16.978.300.000.000.000      197.315  22.484.699.999.999.900
# 1     16.978.300.000.000.000      197.315  22.484.699.999.999.900
# 2     14.129.600.000.000.000      214.560                 311.688
# 3     14.129.600.000.000.000      214.560                 311.688
# 4     14.129.600.000.000.000      214.560                 311.688
# ...                      ...          ...                     ...
# 1710                 161.756      552.385               1.380.286
# 1711                 161.756      552.385               1.380.286
# 1712                 161.756      552.385               1.380.286
# 1713                 161.756      552.385               1.380.286
# 1714                 161.756      552.385               1.380.286
#
#        price_range
# 0       high price
# 1        low price
# 2        low price
# 3     medium price
# 4       high price
# ...            ...
# 1710  medium price
# 1711  medium price
# 1712  medium price
# 1713  medium price
# 1714  medium price
#
# [1715 rows x 31 columns]>

# %%
df.nunique()
# Out:
# phone_brand             22
# phone_model            472
# store                    8
# price                 1250
# currency                 3
# price_USD             1429
# storage                  6
# ram                      8
# Launch                 337
# Dimensions             397
# Weight                 119
# Display_Type           262
# Display_Size            50
# Display_Resolution      68
# OS                     213
# NFC                      2
# USB                     35
# BATTERY                 90
# Features_Sensors        63
# Colors                 416
# Video                  164
# Chipset                158
# CPU                    128
# GPU                     76
# Year                     8
# Foldable                 2
# PPI_Density             94
# quantile_10              8
# quantile_50              8
# quantile_90              8
# price_range              3
# dtype: int64

# %%
df['phone_brand'].nunique()
# Out:
# 22

# %%
df.isnull().sum()
# Out:
# phone_brand           0
# phone_model           0
# store                 0
# price                 0
# currency              0
# price_USD             0
# storage               0
# ram                   0
# Launch                0
# Dimensions            0
# Weight                3
# Display_Type          0
# Display_Size          0
# Display_Resolution    0
# OS                    0
# NFC                   0
# USB                   0
# BATTERY               0
# Features_Sensors      0
# Colors                0
# Video                 0
# Chipset               0
# CPU                   0
# GPU                   0
# Year                  0
# Foldable              0
# PPI_Density           0
# quantile_10           0
# quantile_50           0
# quantile_90           0
# price_range           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1715 entries, 0 to 1714
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   phone_brand         1715 non-null   object
#  1   phone_model         1715 non-null   object
#  2   store               1715 non-null   object
#  3   price               1715 non-null   float64
#  4   currency            1715 non-null   object
#  5   price_USD           1715 non-null   float64
#  6   storage             1715 non-null   int64
#  7   ram                 1715 non-null   int64
#  8   Launch              1715 non-null   object
#  9   Dimensions          1715 non-null   object
#  10  Weight              1712 non-null   float64
#  11  Display_Type        1715 non-null   object
#  12  Display_Size        1715 non-null   float64
#  13  Display_Resolution  1715 non-null   object
#  14  OS                  1715 non-null   object
#  15  NFC                 1715 non-null   int64
#  16  USB                 1715 non-null   object
#  17  BATTERY             1715 non-null   int64
#  18  Features_Sensors    1715 non-null   object
#  19  Colors              1715 non-null   object
#  20  Video               1715 non-null   object
#  21  Chipset             1715 non-null   object
#  22  CPU                 1715 non-null   object
#  23  GPU                 1715 non-null   object
#  24  Year                1715 non-null   int64
#  25  Foldable            1715 non-null   int64
#  26  PPI_Density         1715 non-null   int64
#  27  quantile_10         1715 non-null   object
#  28  quantile_50         1715 non-null   float64
#  29  quantile_90         1715 non-null   object
#  30  price_range         1715 non-null   object
# dtypes: float64(5), int64(7), object(19)
# memory usage: 415.5+ KB
